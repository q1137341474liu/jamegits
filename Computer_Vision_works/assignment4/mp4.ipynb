# %%
# you will be prompted with a window asking to grant permissions
from google.colab import drive
drive.mount("/content/drive")

# %%
# fill in the path in your Google Drive in the string below. Note: do not escape slashes or spaces
import os
datadir = "/content/assignment4"
if not os.path.exists(datadir):
  # !ln -s "/content/drive/MyDrive/MP4/" $datadir # TODO: Fill your Assignment 4 path
os.chdir(datadir)
# !pwd

# %%
# NOTE: Loading data from Google Drive is VERY SLOW. Therefore, we download the data to a local storage
# specified by VOC_PATH.
# This means the data would have be re-downloaded everytime.
# Change this path if you are running this script locally
VOC_PATH="assignment4_starter_sp25/data/voc2007.txt"

# !chmod u+x ./download_data.sh
# !sed -i 's/\r//g' ./download_data.sh
# !cat ./download_data.sh
# !bash ./download_data.sh $VOC_PATH

# %%
import os
import random

import cv2
import numpy as np

import torch
from torch.utils.data import DataLoader

from src.resnet_yolo import resnet50
import yolo_loss
from src.dataset import VocDetectorDataset
from src.eval_voc import evaluate
from src.predict import predict_image
from src.config import VOC_CLASSES, COLORS
from kaggle_submission import output_submission_csv

import matplotlib.pyplot as plt
import collections

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Initialization

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# YOLO network hyperparameters
B = 2  # number of bounding box predictions per cell
S = 14  # width/height of network output grid (larger than 7x7 from paper since we use a different network)

# %%
# We recommend tuning only the batch size; the remaining hyperparameters should work well
# with the default values. However, you are free to experiment with them.

learning_rate = 0.001
num_epochs = 50
batch_size = 12

# Yolo loss component coefficients (as given in Yolo v1 paper)
lambda_coord = 5
lambda_noobj = 0.5

# %% [markdown]
# ## Reading Pascal Data

# %% [markdown]
# Since Pascal is a small dataset (5000 in train+val) we have combined the train and val splits to train our detector. This is not typically a good practice, but we will make an exception in this case to be able to get reasonable detection results with a comparatively small object detection dataset.
#
# The train dataset loader also using a variety of data augmentation techniques including random shift, scaling, crop, and flips. Data augmentation is slightly more complicated for detection datasets since the bounding box annotations must be kept consistent throughout the transformations.
#
# Since the output of the detector network we train is an SxSx(B*5+C), we use an encoder to convert the original bounding box coordinates into relative grid bounding box coordinates corresponding to the expected output. We also use a decoder which allows us to convert the opposite direction into image coordinate bounding boxes.

# %%
file_root_train = os.path.join(VOC_PATH, 'VOCdevkit_2007/VOC2007/JPEGImages/')
annotation_file_train = 'data/voc2007.txt'

train_dataset = VocDetectorDataset(root_img_dir=file_root_train,dataset_file=annotation_file_train,train=True, S=S)
train_loader = DataLoader(train_dataset,batch_size=batch_size,shuffle=True,num_workers=2)
print('Loaded %d train images' % len(train_dataset))
# Out:
# Initializing dataset
# Loaded 5011 train images

# %%
file_root_test = os.path.join(VOC_PATH, 'VOCdevkit_2007/VOC2007test/JPEGImages/')
annotation_file_test = 'data/voc2007test.txt'

test_dataset = VocDetectorDataset(root_img_dir=file_root_test,dataset_file=annotation_file_test,train=False, S=S)
test_loader = DataLoader(test_dataset,batch_size=batch_size,shuffle=False,num_workers=2)
print('Loaded %d test images' % len(test_dataset))
# Out:
# Initializing dataset
# Loaded 4950 test images

# %%
data = train_dataset[0]

# %% [markdown]
# ## Initializing the network
#
# ## **Start from here if you modified yolo_loss.py and wish to retrain**

# %% [markdown]
# To implement Yolo we will rely on a pretrained classifier as the backbone for our detection network. PyTorch offers a variety of models which are pretrained on ImageNet in the [`torchvision.models`](https://pytorch.org/docs/stable/torchvision/models.html) package. In particular, we will use the ResNet50 architecture as a base for our detector. This is different from the base architecture in the Yolo paper and also results in a different output grid size (14x14 instead of 7x7).
#
# Models are typically pretrained on ImageNet since the dataset is very large (> 1 million images) and widely used. The pretrained model provides a very useful weight initialization for our detector, so that the network is able to learn quickly and effectively.

# %%
load_network_path = None
pretrained = True

# use to load a previously trained network
if load_network_path is not None:
    print('Loading saved network from {}'.format(load_network_path))
    net = resnet50().to(device)
    net.load_state_dict(torch.load(load_network_path))
else:
    print('Load pre-trained model')
    net = resnet50(pretrained=pretrained).to(device)
# Out:
# Load pre-trained model

# %% [markdown]
# ## Set up training tools

# %%
from importlib import reload
reload(yolo_loss) # update the import if the implementation has changed

criterion = yolo_loss.YoloLoss(S, B, lambda_coord, lambda_noobj)
optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)

# %% [markdown]
# ## Train detector

# %%
best_test_loss = np.inf
learning_rate = learning_rate

os.makedirs('./checkpoints', exist_ok=True)
for epoch in range(num_epochs):
    net.train()

    # Update learning rate late in training
    if epoch == 30 or epoch == 40:
        learning_rate /= 10.0

    for param_group in optimizer.param_groups:
        param_group['lr'] = learning_rate

    print('\n\nStarting epoch %d / %d' % (epoch + 1, num_epochs))
    print('Learning Rate for this epoch: {}'.format(learning_rate))

    total_loss = collections.defaultdict(int)

    for i, data in enumerate(train_loader):
        data = (item.to(device) for item in data)
        images, target_boxes, target_cls, has_object_map = data
        pred = net(images)
        loss_dict = criterion(pred, target_boxes, target_cls, has_object_map)
        for key in loss_dict:
            total_loss[key] += loss_dict[key].item()

        optimizer.zero_grad()
        loss_dict['total_loss'].backward()
        optimizer.step()

        if (i+1) % 50 == 0:
            outstring = 'Epoch [%d/%d], Iter [%d/%d], Loss: ' % ((epoch+1, num_epochs, i+1, len(train_loader)))
            outstring += ', '.join( "%s=%.3f" % (key[:-5], val / (i+1)) for key, val in total_loss.items() )
            print(outstring)

    # evaluate the network on the test data
    if (epoch + 1) % 5 == 0:
        test_aps = evaluate(net, test_dataset_file=annotation_file_test, img_root=file_root_test)
        print(epoch, test_aps)
    with torch.no_grad():
        test_loss = 0.0
        net.eval()
        for i, data in enumerate(test_loader):
            data = (item.to(device) for item in data)
            images, target_boxes, target_cls, has_object_map = data

            pred = net(images)
            loss_dict = criterion(pred, target_boxes, target_cls, has_object_map)
            test_loss += loss_dict['total_loss'].item()
        test_loss /= len(test_loader)

    if best_test_loss > test_loss:
        best_test_loss = test_loss
        print('Updating best test loss: %.5f' % best_test_loss)
        torch.save(net.state_dict(),'checkpoints/best_detector.pth')

    if (epoch+1) in [5, 10, 20, 30, 40]:
        torch.save(net.state_dict(),'checkpoints/detector_epoch_%d.pth' % (epoch+1))

    torch.save(net.state_dict(),'checkpoints/detector.pth')
# Out:
# Starting epoch 1 / 50
# Learning Rate for this epoch: 0.001
# Epoch [1/50], Iter [50/418], Loss: total=25.856, reg=51.227, containing_obj=3.442, no_obj=149.443, cls=106.164
# Epoch [1/50], Iter [100/418], Loss: total=17.371, reg=44.865, containing_obj=4.422, no_obj=77.362, cls=81.802
# Epoch [1/50], Iter [150/418], Loss: total=14.132, reg=40.847, containing_obj=5.056, no_obj=52.798, cls=70.878
# Epoch [1/50], Iter [200/418], Loss: total=12.277, reg=37.904, containing_obj=5.519, no_obj=40.323, cls=63.576
# Epoch [1/50], Iter [250/418], Loss: total=11.062, reg=36.028, containing_obj=5.872, no_obj=32.742, cls=58.105
# Epoch [1/50], Iter [300/418], Loss: total=10.197, reg=34.678, containing_obj=6.203, no_obj=27.633, cls=53.845
# Epoch [1/50], Iter [350/418], Loss: total=9.509, reg=33.484, containing_obj=6.406, no_obj=23.949, cls=50.272
# Epoch [1/50], Iter [400/418], Loss: total=8.986, reg=32.652, containing_obj=6.602, no_obj=21.163, cls=47.417
# Updating best test loss: 5.36588
#
#
# Starting epoch 2 / 50
# Learning Rate for this epoch: 0.001
# Epoch [2/50], Iter [50/418], Loss: total=5.192, reg=26.337, containing_obj=8.192, no_obj=1.473, cls=26.296
# Epoch [2/50], Iter [100/418], Loss: total=5.137, reg=25.940, containing_obj=8.245, no_obj=1.419, cls=26.037
# Epoch [2/50], Iter [150/418], Loss: total=5.103, reg=26.000, containing_obj=8.382, no_obj=1.371, cls=25.483
# Epoch [2/50], Iter [200/418], Loss: total=5.089, reg=26.053, containing_obj=8.504, no_obj=1.330, cls=25.181
# Epoch [2/50], Iter [250/418], Loss: total=5.003, reg=25.676, containing_obj=8.458, no_obj=1.293, cls=24.607
# Epoch [2/50], Iter [300/418], Loss: total=4.988, reg=25.712, containing_obj=8.480, no_obj=1.259, cls=24.405
# Epoch [2/50], Iter [350/418], Loss: total=4.959, reg=25.664, containing_obj=8.540, no_obj=1.230, cls=24.070
# Epoch [2/50], Iter [400/418], Loss: total=4.934, reg=25.506, containing_obj=8.598, no_obj=1.203, cls=23.904
# Updating best test loss: 4.70678
#
#
# Starting epoch 3 / 50
# Learning Rate for this epoch: 0.001
# Epoch [3/50], Iter [50/418], Loss: total=4.778, reg=25.795, containing_obj=9.079, no_obj=0.975, cls=21.485
# Epoch [3/50], Iter [100/418], Loss: total=4.767, reg=25.401, containing_obj=9.380, no_obj=0.965, cls=21.458
# Epoch [3/50], Iter [150/418], Loss: total=4.678, reg=24.849, containing_obj=9.179, no_obj=0.957, cls=21.151
# Epoch [3/50], Iter [200/418], Loss: total=4.627, reg=24.798, containing_obj=9.144, no_obj=0.949, cls=20.636
# Epoch [3/50], Iter [250/418], Loss: total=4.596, reg=24.669, containing_obj=9.150, no_obj=0.945, cls=20.392
# Epoch [3/50], Iter [300/418], Loss: total=4.552, reg=24.415, containing_obj=9.142, no_obj=0.943, cls=20.118
# Epoch [3/50], Iter [350/418], Loss: total=4.514, reg=24.132, containing_obj=9.112, no_obj=0.942, cls=19.987
# Epoch [3/50], Iter [400/418], Loss: total=4.469, reg=23.937, containing_obj=9.084, no_obj=0.943, cls=19.669
# Updating best test loss: 4.35806
#
#
# Starting epoch 4 / 50
# Learning Rate for this epoch: 0.001
# Epoch [4/50], Iter [50/418], Loss: total=4.390, reg=23.737, containing_obj=9.298, no_obj=0.984, cls=18.659
# Epoch [4/50], Iter [100/418], Loss: total=4.178, reg=22.386, containing_obj=8.891, no_obj=1.001, cls=17.864
# Epoch [4/50], Iter [150/418], Loss: total=4.245, reg=22.946, containing_obj=9.002, no_obj=1.013, cls=17.982
# Epoch [4/50], Iter [200/418], Loss: total=4.235, reg=22.983, containing_obj=9.115, no_obj=1.016, cls=17.708
# Epoch [4/50], Iter [250/418], Loss: total=4.217, reg=22.925, containing_obj=9.057, no_obj=1.031, cls=17.586
# Epoch [4/50], Iter [300/418], Loss: total=4.182, reg=22.760, containing_obj=9.026, no_obj=1.043, cls=17.359
# Epoch [4/50], Iter [350/418], Loss: total=4.183, reg=22.762, containing_obj=9.064, no_obj=1.047, cls=17.319
# Epoch [4/50], Iter [400/418], Loss: total=4.162, reg=22.624, containing_obj=9.023, no_obj=1.057, cls=17.238
# Updating best test loss: 4.13973
#
#
# Starting epoch 5 / 50
# Learning Rate for this epoch: 0.001
# Epoch [5/50], Iter [50/418], Loss: total=4.090, reg=22.457, containing_obj=9.156, no_obj=1.152, cls=16.310
# Epoch [5/50], Iter [100/418], Loss: total=3.963, reg=21.634, containing_obj=9.013, no_obj=1.156, cls=15.752
# Epoch [5/50], Iter [150/418], Loss: total=3.934, reg=21.714, containing_obj=8.914, no_obj=1.157, cls=15.423
# Epoch [5/50], Iter [200/418], Loss: total=3.929, reg=21.800, containing_obj=8.945, no_obj=1.158, cls=15.243
# Epoch [5/50], Iter [250/418], Loss: total=3.933, reg=21.761, containing_obj=8.944, no_obj=1.163, cls=15.323
# Epoch [5/50], Iter [300/418], Loss: total=3.937, reg=21.776, containing_obj=8.987, no_obj=1.158, cls=15.320
# Epoch [5/50], Iter [350/418], Loss: total=3.910, reg=21.718, containing_obj=8.916, no_obj=1.163, cls=15.120
# Epoch [5/50], Iter [400/418], Loss: total=3.929, reg=21.869, containing_obj=8.983, no_obj=1.161, cls=15.131
# ---Evaluate model on test samples---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [00:59<00:00, 83.29it/s]
# ---class aeroplane ap 0.03343957115009747---
# ---class bicycle ap 0.13519782403495284---
# ---class bird ap 0.015212981744421908---
# ---class boat ap 0.0--- (no predictions for this class)
# ---class bottle ap 0.0--- (no predictions for this class)
# ---class bus ap 0.0--- (no predictions for this class)
# ---class car ap 0.3295691198839656---
# ---class cat ap 0.0--- (no predictions for this class)
# ---class chair ap 0.05435188822815862---
# ---class cow ap 0.0--- (no predictions for this class)
# ---class diningtable ap 0.0--- (no predictions for this class)
# ---class dog ap 0.09736027185157725---
# ---class horse ap 0.014511494252873564---
# ---class motorbike ap 0.0--- (no predictions for this class)
# ---class person ap 0.18906783544144307---
# ---class pottedplant ap 0.013139470151964594---
# ---class sheep ap 0.0--- (no predictions for this class)
# ---class sofa ap 0.0--- (no predictions for this class)
# ---class train ap 0.0--- (no predictions for this class)
# ---class tvmonitor ap 0.13473178709286654---
# ---map 0.05082911219161608---
# 4 [np.float64(0.03343957115009747), np.float64(0.13519782403495284), np.float64(0.015212981744421908), 0.0, 0.0, 0.0, np.float64(0.3295691198839656), 0.0, np.float64(0.05435188822815862), 0.0, 0.0, np.float64(0.09736027185157725), np.float64(0.014511494252873564), 0.0, np.float64(0.18906783544144307), np.float64(0.013139470151964594), 0.0, 0.0, 0.0, np.float64(0.13473178709286654)]
# Updating best test loss: 3.91364
#
#
# Starting epoch 6 / 50
# Learning Rate for this epoch: 0.001
# Epoch [6/50], Iter [50/418], Loss: total=3.772, reg=21.006, containing_obj=9.264, no_obj=1.143, cls=13.854
# Epoch [6/50], Iter [100/418], Loss: total=3.762, reg=21.052, containing_obj=9.303, no_obj=1.133, cls=13.654
# Epoch [6/50], Iter [150/418], Loss: total=3.732, reg=20.854, containing_obj=9.202, no_obj=1.164, cls=13.566
# Epoch [6/50], Iter [200/418], Loss: total=3.706, reg=20.687, containing_obj=9.153, no_obj=1.183, cls=13.443
# Epoch [6/50], Iter [250/418], Loss: total=3.676, reg=20.576, containing_obj=9.051, no_obj=1.190, cls=13.289
# Epoch [6/50], Iter [300/418], Loss: total=3.680, reg=20.682, containing_obj=9.031, no_obj=1.187, cls=13.257
# Epoch [6/50], Iter [350/418], Loss: total=3.691, reg=20.745, containing_obj=9.032, no_obj=1.190, cls=13.327
# Epoch [6/50], Iter [400/418], Loss: total=3.707, reg=20.926, containing_obj=9.077, no_obj=1.191, cls=13.285
# Updating best test loss: 3.66709
#
#
# Starting epoch 7 / 50
# Learning Rate for this epoch: 0.001
# Epoch [7/50], Iter [50/418], Loss: total=3.636, reg=21.327, containing_obj=9.215, no_obj=1.208, cls=11.878
# Epoch [7/50], Iter [100/418], Loss: total=3.633, reg=21.125, containing_obj=9.316, no_obj=1.169, cls=11.986
# Epoch [7/50], Iter [150/418], Loss: total=3.646, reg=21.337, containing_obj=9.351, no_obj=1.170, cls=11.897
# Epoch [7/50], Iter [200/418], Loss: total=3.601, reg=21.029, containing_obj=9.259, no_obj=1.179, cls=11.749
# Epoch [7/50], Iter [250/418], Loss: total=3.555, reg=20.730, containing_obj=9.096, no_obj=1.181, cls=11.647
# Epoch [7/50], Iter [300/418], Loss: total=3.538, reg=20.640, containing_obj=9.141, no_obj=1.182, cls=11.488
# Epoch [7/50], Iter [350/418], Loss: total=3.546, reg=20.721, containing_obj=9.162, no_obj=1.198, cls=11.467
# Epoch [7/50], Iter [400/418], Loss: total=3.544, reg=20.767, containing_obj=9.120, no_obj=1.211, cls=11.435
# Updating best test loss: 3.51099
#
#
# Starting epoch 8 / 50
# Learning Rate for this epoch: 0.001
# Epoch [8/50], Iter [50/418], Loss: total=3.482, reg=20.367, containing_obj=9.478, no_obj=1.237, cls=10.703
# Epoch [8/50], Iter [100/418], Loss: total=3.454, reg=20.159, containing_obj=9.473, no_obj=1.283, cls=10.539
# Epoch [8/50], Iter [150/418], Loss: total=3.424, reg=20.012, containing_obj=9.321, no_obj=1.279, cls=10.474
# Epoch [8/50], Iter [200/418], Loss: total=3.379, reg=19.858, containing_obj=9.195, no_obj=1.272, cls=10.221
# Epoch [8/50], Iter [250/418], Loss: total=3.388, reg=19.870, containing_obj=9.174, no_obj=1.269, cls=10.349
# Epoch [8/50], Iter [300/418], Loss: total=3.379, reg=19.870, containing_obj=9.188, no_obj=1.268, cls=10.218
# Epoch [8/50], Iter [350/418], Loss: total=3.344, reg=19.666, containing_obj=9.135, no_obj=1.286, cls=10.037
# Epoch [8/50], Iter [400/418], Loss: total=3.346, reg=19.667, containing_obj=9.098, no_obj=1.296, cls=10.087
# Updating best test loss: 3.39379
#
#
# Starting epoch 9 / 50
# Learning Rate for this epoch: 0.001
# Epoch [9/50], Iter [50/418], Loss: total=3.059, reg=18.392, containing_obj=8.975, no_obj=1.300, cls=8.039
# Epoch [9/50], Iter [100/418], Loss: total=3.096, reg=18.335, containing_obj=8.998, no_obj=1.337, cls=8.484
# Epoch [9/50], Iter [150/418], Loss: total=3.142, reg=18.726, containing_obj=9.017, no_obj=1.318, cls=8.642
# Epoch [9/50], Iter [200/418], Loss: total=3.205, reg=19.293, containing_obj=9.152, no_obj=1.311, cls=8.702
# Epoch [9/50], Iter [250/418], Loss: total=3.213, reg=19.369, containing_obj=9.212, no_obj=1.319, cls=8.654
# Epoch [9/50], Iter [300/418], Loss: total=3.208, reg=19.365, containing_obj=9.163, no_obj=1.347, cls=8.617
# Epoch [9/50], Iter [350/418], Loss: total=3.187, reg=19.223, containing_obj=9.138, no_obj=1.346, cls=8.537
# Epoch [9/50], Iter [400/418], Loss: total=3.175, reg=19.100, containing_obj=9.125, no_obj=1.344, cls=8.534
# Updating best test loss: 3.23184
#
#
# Starting epoch 10 / 50
# Learning Rate for this epoch: 0.001
# Epoch [10/50], Iter [50/418], Loss: total=3.068, reg=18.760, containing_obj=9.072, no_obj=1.404, cls=7.582
# Epoch [10/50], Iter [100/418], Loss: total=3.119, reg=18.763, containing_obj=9.265, no_obj=1.394, cls=8.000
# Epoch [10/50], Iter [150/418], Loss: total=3.066, reg=18.510, containing_obj=9.071, no_obj=1.415, cls=7.795
# Epoch [10/50], Iter [200/418], Loss: total=3.082, reg=18.576, containing_obj=9.033, no_obj=1.399, cls=7.979
# Epoch [10/50], Iter [250/418], Loss: total=3.088, reg=18.638, containing_obj=9.084, no_obj=1.401, cls=7.929
# Epoch [10/50], Iter [300/418], Loss: total=3.083, reg=18.588, containing_obj=9.086, no_obj=1.417, cls=7.902
# Epoch [10/50], Iter [350/418], Loss: total=3.082, reg=18.653, containing_obj=9.033, no_obj=1.419, cls=7.884
# Epoch [10/50], Iter [400/418], Loss: total=3.100, reg=18.776, containing_obj=9.052, no_obj=1.418, cls=7.955
# ---Evaluate model on test samples---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [01:00<00:00, 81.42it/s]
# ---class aeroplane ap 0.34989932288818687---
# ---class bicycle ap 0.347749872447871---
# ---class bird ap 0.26114045074733244---
# ---class boat ap 0.039101872783008675---
# ---class bottle ap 0.045094597350326435---
# ---class bus ap 0.28298013212583073---
# ---class car ap 0.562997963841209---
# ---class cat ap 0.5808022637047963---
# ---class chair ap 0.15085444631403966---
# ---class cow ap 0.15279777763804253---
# ---class diningtable ap 0.00022065313327449248---
# ---class dog ap 0.4941139987941897---
# ---class horse ap 0.4987407114910024---
# ---class motorbike ap 0.4859871679367955---
# ---class person ap 0.3374604076735571---
# ---class pottedplant ap 0.05606338423529933---
# ---class sheep ap 0.13503859403031945---
# ---class sofa ap 0.07154137878927797---
# ---class train ap 0.4825971397868719---
# ---class tvmonitor ap 0.3092732339215931---
# ---map 0.2822227684816413---
# 9 [np.float64(0.34989932288818687), np.float64(0.347749872447871), np.float64(0.26114045074733244), np.float64(0.039101872783008675), np.float64(0.045094597350326435), np.float64(0.28298013212583073), np.float64(0.562997963841209), np.float64(0.5808022637047963), np.float64(0.15085444631403966), np.float64(0.15279777763804253), np.float64(0.00022065313327449248), np.float64(0.4941139987941897), np.float64(0.4987407114910024), np.float64(0.4859871679367955), np.float64(0.3374604076735571), np.float64(0.05606338423529933), np.float64(0.13503859403031945), np.float64(0.07154137878927797), np.float64(0.4825971397868719), np.float64(0.3092732339215931)]
# Updating best test loss: 3.15669
#
#
# Starting epoch 11 / 50
# Learning Rate for this epoch: 0.001
# Epoch [11/50], Iter [50/418], Loss: total=2.980, reg=17.944, containing_obj=9.186, no_obj=1.588, cls=7.046
# Epoch [11/50], Iter [100/418], Loss: total=3.060, reg=18.712, containing_obj=9.127, no_obj=1.571, cls=7.305
# Epoch [11/50], Iter [150/418], Loss: total=3.082, reg=18.776, containing_obj=9.172, no_obj=1.555, cls=7.481
# Epoch [11/50], Iter [200/418], Loss: total=3.048, reg=18.627, containing_obj=9.031, no_obj=1.549, cls=7.366
# Epoch [11/50], Iter [250/418], Loss: total=3.024, reg=18.429, containing_obj=9.041, no_obj=1.552, cls=7.270
# Epoch [11/50], Iter [300/418], Loss: total=3.028, reg=18.424, containing_obj=8.996, no_obj=1.559, cls=7.356
# Epoch [11/50], Iter [350/418], Loss: total=2.989, reg=18.184, containing_obj=8.909, no_obj=1.567, cls=7.207
# Epoch [11/50], Iter [400/418], Loss: total=2.983, reg=18.171, containing_obj=8.901, no_obj=1.574, cls=7.153
# Updating best test loss: 3.09565
#
#
# Starting epoch 12 / 50
# Learning Rate for this epoch: 0.001
# Epoch [12/50], Iter [50/418], Loss: total=2.810, reg=17.296, containing_obj=8.727, no_obj=1.665, cls=6.037
# Epoch [12/50], Iter [100/418], Loss: total=2.894, reg=17.816, containing_obj=8.752, no_obj=1.653, cls=6.512
# Epoch [12/50], Iter [150/418], Loss: total=2.974, reg=18.242, containing_obj=8.989, no_obj=1.615, cls=6.843
# Epoch [12/50], Iter [200/418], Loss: total=2.958, reg=18.179, containing_obj=8.902, no_obj=1.635, cls=6.784
# Epoch [12/50], Iter [250/418], Loss: total=2.923, reg=17.898, containing_obj=8.823, no_obj=1.652, cls=6.699
# Epoch [12/50], Iter [300/418], Loss: total=2.912, reg=17.895, containing_obj=8.784, no_obj=1.661, cls=6.605
# Epoch [12/50], Iter [350/418], Loss: total=2.888, reg=17.733, containing_obj=8.715, no_obj=1.677, cls=6.531
# Epoch [12/50], Iter [400/418], Loss: total=2.886, reg=17.795, containing_obj=8.691, no_obj=1.679, cls=6.472
# Updating best test loss: 2.99688
#
#
# Starting epoch 13 / 50
# Learning Rate for this epoch: 0.001
# Epoch [13/50], Iter [50/418], Loss: total=2.829, reg=17.499, containing_obj=8.538, no_obj=1.767, cls=6.147
# Epoch [13/50], Iter [100/418], Loss: total=2.826, reg=17.289, containing_obj=8.660, no_obj=1.743, cls=6.214
# Epoch [13/50], Iter [150/418], Loss: total=2.875, reg=17.658, containing_obj=8.826, no_obj=1.756, cls=6.262
# Epoch [13/50], Iter [200/418], Loss: total=2.878, reg=17.736, containing_obj=8.888, no_obj=1.750, cls=6.161
# Epoch [13/50], Iter [250/418], Loss: total=2.845, reg=17.547, containing_obj=8.742, no_obj=1.775, cls=6.072
# Epoch [13/50], Iter [300/418], Loss: total=2.822, reg=17.419, containing_obj=8.672, no_obj=1.771, cls=5.997
# Epoch [13/50], Iter [350/418], Loss: total=2.816, reg=17.385, containing_obj=8.666, no_obj=1.756, cls=5.980
# Epoch [13/50], Iter [400/418], Loss: total=2.793, reg=17.244, containing_obj=8.631, no_obj=1.756, cls=5.884
# Updating best test loss: 2.94091
#
#
# Starting epoch 14 / 50
# Learning Rate for this epoch: 0.001
# Epoch [14/50], Iter [50/418], Loss: total=2.654, reg=16.082, containing_obj=8.350, no_obj=1.797, cls=5.617
# Epoch [14/50], Iter [100/418], Loss: total=2.727, reg=16.843, containing_obj=8.479, no_obj=1.736, cls=5.670
# Epoch [14/50], Iter [150/418], Loss: total=2.736, reg=16.894, containing_obj=8.523, no_obj=1.723, cls=5.691
# Epoch [14/50], Iter [200/418], Loss: total=2.797, reg=17.380, containing_obj=8.780, no_obj=1.708, cls=5.696
# Epoch [14/50], Iter [250/418], Loss: total=2.752, reg=16.986, containing_obj=8.632, no_obj=1.736, cls=5.674
# Epoch [14/50], Iter [300/418], Loss: total=2.718, reg=16.684, containing_obj=8.516, no_obj=1.757, cls=5.658
# Epoch [14/50], Iter [350/418], Loss: total=2.736, reg=16.801, containing_obj=8.561, no_obj=1.744, cls=5.722
# Epoch [14/50], Iter [400/418], Loss: total=2.736, reg=16.836, containing_obj=8.558, no_obj=1.760, cls=5.676
# Updating best test loss: 2.91107
#
#
# Starting epoch 15 / 50
# Learning Rate for this epoch: 0.001
# Epoch [15/50], Iter [50/418], Loss: total=2.722, reg=16.748, containing_obj=8.454, no_obj=1.863, cls=5.596
# Epoch [15/50], Iter [100/418], Loss: total=2.657, reg=16.268, containing_obj=8.471, no_obj=1.871, cls=5.280
# Epoch [15/50], Iter [150/418], Loss: total=2.643, reg=16.234, containing_obj=8.458, no_obj=1.848, cls=5.172
# Epoch [15/50], Iter [200/418], Loss: total=2.654, reg=16.375, containing_obj=8.484, no_obj=1.828, cls=5.159
# Epoch [15/50], Iter [250/418], Loss: total=2.659, reg=16.341, containing_obj=8.526, no_obj=1.835, cls=5.202
# Epoch [15/50], Iter [300/418], Loss: total=2.662, reg=16.377, containing_obj=8.548, no_obj=1.831, cls=5.187
# Epoch [15/50], Iter [350/418], Loss: total=2.678, reg=16.450, containing_obj=8.581, no_obj=1.849, cls=5.252
# Epoch [15/50], Iter [400/418], Loss: total=2.659, reg=16.307, containing_obj=8.534, no_obj=1.847, cls=5.226
# ---Evaluate model on test samples---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [01:00<00:00, 82.21it/s]
# ---class aeroplane ap 0.392042685410119---
# ---class bicycle ap 0.5122746347119733---
# ---class bird ap 0.3496530144828455---
# ---class boat ap 0.17145714511876173---
# ---class bottle ap 0.07658768128437929---
# ---class bus ap 0.5117768678443072---
# ---class car ap 0.5700976405024845---
# ---class cat ap 0.6434646265884537---
# ---class chair ap 0.20318415241460064---
# ---class cow ap 0.3071598695358114---
# ---class diningtable ap 0.0985202401493572---
# ---class dog ap 0.5090510305047973---
# ---class horse ap 0.5755111461090617---
# ---class motorbike ap 0.4902625400556426---
# ---class person ap 0.38774648453455296---
# ---class pottedplant ap 0.11333318931408243---
# ---class sheep ap 0.3672815228057301---
# ---class sofa ap 0.32929647004841933---
# ---class train ap 0.5443135843799843---
# ---class tvmonitor ap 0.3890744295316193---
# ---map 0.37710444776634916---
# 14 [np.float64(0.392042685410119), np.float64(0.5122746347119733), np.float64(0.3496530144828455), np.float64(0.17145714511876173), np.float64(0.07658768128437929), np.float64(0.5117768678443072), np.float64(0.5700976405024845), np.float64(0.6434646265884537), np.float64(0.20318415241460064), np.float64(0.3071598695358114), np.float64(0.0985202401493572), np.float64(0.5090510305047973), np.float64(0.5755111461090617), np.float64(0.4902625400556426), np.float64(0.38774648453455296), np.float64(0.11333318931408243), np.float64(0.3672815228057301), np.float64(0.32929647004841933), np.float64(0.5443135843799843), np.float64(0.3890744295316193)]
# Updating best test loss: 2.85401
#
#
# Starting epoch 16 / 50
# Learning Rate for this epoch: 0.001
# Epoch [16/50], Iter [50/418], Loss: total=2.640, reg=16.197, containing_obj=8.657, no_obj=1.780, cls=5.048
# Epoch [16/50], Iter [100/418], Loss: total=2.588, reg=16.085, containing_obj=8.307, no_obj=1.866, cls=4.798
# Epoch [16/50], Iter [150/418], Loss: total=2.601, reg=16.121, containing_obj=8.357, no_obj=1.877, cls=4.859
# Epoch [16/50], Iter [200/418], Loss: total=2.626, reg=16.152, containing_obj=8.515, no_obj=1.870, cls=4.977
# Epoch [16/50], Iter [250/418], Loss: total=2.599, reg=15.925, containing_obj=8.462, no_obj=1.884, cls=4.921
# Epoch [16/50], Iter [300/418], Loss: total=2.609, reg=16.046, containing_obj=8.483, no_obj=1.884, cls=4.898
# Epoch [16/50], Iter [350/418], Loss: total=2.589, reg=15.910, containing_obj=8.403, no_obj=1.895, cls=4.858
# Epoch [16/50], Iter [400/418], Loss: total=2.589, reg=15.943, containing_obj=8.364, no_obj=1.881, cls=4.877
# Updating best test loss: 2.83408
#
#
# Starting epoch 17 / 50
# Learning Rate for this epoch: 0.001
# Epoch [17/50], Iter [50/418], Loss: total=2.466, reg=15.049, containing_obj=8.178, no_obj=1.986, cls=4.373
# Epoch [17/50], Iter [100/418], Loss: total=2.554, reg=15.457, containing_obj=8.459, no_obj=1.896, cls=4.837
# Epoch [17/50], Iter [150/418], Loss: total=2.585, reg=15.780, containing_obj=8.458, no_obj=1.936, cls=4.849
# Epoch [17/50], Iter [200/418], Loss: total=2.549, reg=15.630, containing_obj=8.323, no_obj=1.938, cls=4.700
# Epoch [17/50], Iter [250/418], Loss: total=2.567, reg=15.794, containing_obj=8.383, no_obj=1.931, cls=4.692
# Epoch [17/50], Iter [300/418], Loss: total=2.563, reg=15.733, containing_obj=8.440, no_obj=1.921, cls=4.663
# Epoch [17/50], Iter [350/418], Loss: total=2.565, reg=15.778, containing_obj=8.463, no_obj=1.918, cls=4.618
# Epoch [17/50], Iter [400/418], Loss: total=2.558, reg=15.760, containing_obj=8.390, no_obj=1.923, cls=4.624
# Updating best test loss: 2.78055
#
#
# Starting epoch 18 / 50
# Learning Rate for this epoch: 0.001
# Epoch [18/50], Iter [50/418], Loss: total=2.478, reg=15.015, containing_obj=7.971, no_obj=2.039, cls=4.708
# Epoch [18/50], Iter [100/418], Loss: total=2.436, reg=14.795, containing_obj=7.933, no_obj=1.955, cls=4.551
# Epoch [18/50], Iter [150/418], Loss: total=2.487, reg=15.152, containing_obj=8.175, no_obj=1.965, cls=4.550
# Epoch [18/50], Iter [200/418], Loss: total=2.483, reg=15.161, containing_obj=8.192, no_obj=1.940, cls=4.500
# Epoch [18/50], Iter [250/418], Loss: total=2.497, reg=15.259, containing_obj=8.266, no_obj=1.930, cls=4.509
# Epoch [18/50], Iter [300/418], Loss: total=2.483, reg=15.139, containing_obj=8.238, no_obj=1.956, cls=4.460
# Epoch [18/50], Iter [350/418], Loss: total=2.492, reg=15.188, containing_obj=8.292, no_obj=1.959, cls=4.462
# Epoch [18/50], Iter [400/418], Loss: total=2.468, reg=15.041, containing_obj=8.219, no_obj=1.963, cls=4.389
# Updating best test loss: 2.77283
#
#
# Starting epoch 19 / 50
# Learning Rate for this epoch: 0.001
# Epoch [19/50], Iter [50/418], Loss: total=2.366, reg=14.027, containing_obj=8.252, no_obj=1.922, cls=4.194
# Epoch [19/50], Iter [100/418], Loss: total=2.364, reg=14.301, containing_obj=8.102, no_obj=1.965, cls=4.006
# Epoch [19/50], Iter [150/418], Loss: total=2.421, reg=14.755, containing_obj=8.191, no_obj=1.953, cls=4.156
# Epoch [19/50], Iter [200/418], Loss: total=2.431, reg=14.735, containing_obj=8.298, no_obj=1.971, cls=4.162
# Epoch [19/50], Iter [250/418], Loss: total=2.447, reg=14.892, containing_obj=8.318, no_obj=1.982, cls=4.177
# Epoch [19/50], Iter [300/418], Loss: total=2.453, reg=14.986, containing_obj=8.285, no_obj=1.983, cls=4.187
# Epoch [19/50], Iter [350/418], Loss: total=2.451, reg=14.988, containing_obj=8.218, no_obj=1.998, cls=4.205
# Epoch [19/50], Iter [400/418], Loss: total=2.431, reg=14.854, containing_obj=8.172, no_obj=1.993, cls=4.148
# Updating best test loss: 2.74491
#
#
# Starting epoch 20 / 50
# Learning Rate for this epoch: 0.001
# Epoch [20/50], Iter [50/418], Loss: total=2.402, reg=14.500, containing_obj=8.261, no_obj=2.110, cls=3.953
# Epoch [20/50], Iter [100/418], Loss: total=2.372, reg=14.225, containing_obj=8.166, no_obj=2.104, cls=3.970
# Epoch [20/50], Iter [150/418], Loss: total=2.395, reg=14.512, containing_obj=8.114, no_obj=2.109, cls=4.005
# Epoch [20/50], Iter [200/418], Loss: total=2.364, reg=14.372, containing_obj=7.931, no_obj=2.108, cls=3.961
# Epoch [20/50], Iter [250/418], Loss: total=2.342, reg=14.257, containing_obj=7.856, no_obj=2.102, cls=3.885
# Epoch [20/50], Iter [300/418], Loss: total=2.359, reg=14.410, containing_obj=7.867, no_obj=2.096, cls=3.929
# Epoch [20/50], Iter [350/418], Loss: total=2.401, reg=14.731, containing_obj=7.990, no_obj=2.074, cls=4.021
# Epoch [20/50], Iter [400/418], Loss: total=2.401, reg=14.713, containing_obj=8.004, no_obj=2.072, cls=4.020
# ---Evaluate model on test samples---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [01:01<00:00, 80.62it/s]
# ---class aeroplane ap 0.44296481809908034---
# ---class bicycle ap 0.6230940740037425---
# ---class bird ap 0.45217916469617636---
# ---class boat ap 0.3006895600946399---
# ---class bottle ap 0.11523813531481153---
# ---class bus ap 0.5567940202462109---
# ---class car ap 0.6217628424729466---
# ---class cat ap 0.695847273961382---
# ---class chair ap 0.2627154048357202---
# ---class cow ap 0.38556272643041667---
# ---class diningtable ap 0.14563622209726773---
# ---class dog ap 0.5575604241897365---
# ---class horse ap 0.586404804855444---
# ---class motorbike ap 0.5363019002042206---
# ---class person ap 0.4456514710304127---
# ---class pottedplant ap 0.12951228186773017---
# ---class sheep ap 0.4183316742603158---
# ---class sofa ap 0.4524916392865595---
# ---class train ap 0.6296210822357743---
# ---class tvmonitor ap 0.43358836868059764---
# ---map 0.4395973944431593---
# 19 [np.float64(0.44296481809908034), np.float64(0.6230940740037425), np.float64(0.45217916469617636), np.float64(0.3006895600946399), np.float64(0.11523813531481153), np.float64(0.5567940202462109), np.float64(0.6217628424729466), np.float64(0.695847273961382), np.float64(0.2627154048357202), np.float64(0.38556272643041667), np.float64(0.14563622209726773), np.float64(0.5575604241897365), np.float64(0.586404804855444), np.float64(0.5363019002042206), np.float64(0.4456514710304127), np.float64(0.12951228186773017), np.float64(0.4183316742603158), np.float64(0.4524916392865595), np.float64(0.6296210822357743), np.float64(0.43358836868059764)]
# Updating best test loss: 2.72398
#
#
# Starting epoch 21 / 50
# Learning Rate for this epoch: 0.001
# Epoch [21/50], Iter [50/418], Loss: total=2.453, reg=15.062, containing_obj=8.219, no_obj=2.071, cls=4.083
# Epoch [21/50], Iter [100/418], Loss: total=2.461, reg=15.013, containing_obj=8.317, no_obj=2.137, cls=4.059
# Epoch [21/50], Iter [150/418], Loss: total=2.373, reg=14.410, containing_obj=8.111, no_obj=2.107, cls=3.847
# Epoch [21/50], Iter [200/418], Loss: total=2.329, reg=14.031, containing_obj=8.084, no_obj=2.087, cls=3.747
# Epoch [21/50], Iter [250/418], Loss: total=2.326, reg=14.036, containing_obj=8.064, no_obj=2.063, cls=3.756
# Epoch [21/50], Iter [300/418], Loss: total=2.324, reg=14.052, containing_obj=7.975, no_obj=2.061, cls=3.796
# Epoch [21/50], Iter [350/418], Loss: total=2.333, reg=14.110, containing_obj=8.025, no_obj=2.045, cls=3.814
# Epoch [21/50], Iter [400/418], Loss: total=2.353, reg=14.331, containing_obj=8.036, no_obj=2.049, cls=3.820
# Updating best test loss: 2.70092
#
#
# Starting epoch 22 / 50
# Learning Rate for this epoch: 0.001
# Epoch [22/50], Iter [50/418], Loss: total=2.250, reg=13.131, containing_obj=8.123, no_obj=2.137, cls=3.611
# Epoch [22/50], Iter [100/418], Loss: total=2.257, reg=13.316, containing_obj=7.972, no_obj=2.116, cls=3.679
# Epoch [22/50], Iter [150/418], Loss: total=2.281, reg=13.594, containing_obj=8.025, no_obj=2.108, cls=3.644
# Epoch [22/50], Iter [200/418], Loss: total=2.306, reg=13.859, containing_obj=8.026, no_obj=2.092, cls=3.692
# Epoch [22/50], Iter [250/418], Loss: total=2.284, reg=13.690, containing_obj=8.004, no_obj=2.116, cls=3.593
# Epoch [22/50], Iter [300/418], Loss: total=2.291, reg=13.814, containing_obj=7.980, no_obj=2.104, cls=3.596
# Epoch [22/50], Iter [350/418], Loss: total=2.286, reg=13.791, containing_obj=7.957, no_obj=2.101, cls=3.580
# Epoch [22/50], Iter [400/418], Loss: total=2.290, reg=13.823, containing_obj=7.978, no_obj=2.099, cls=3.585
# Updating best test loss: 2.65755
#
#
# Starting epoch 23 / 50
# Learning Rate for this epoch: 0.001
# Epoch [23/50], Iter [50/418], Loss: total=2.249, reg=13.508, containing_obj=7.611, no_obj=2.123, cls=3.747
# Epoch [23/50], Iter [100/418], Loss: total=2.293, reg=13.791, containing_obj=7.954, no_obj=2.118, cls=3.649
# Epoch [23/50], Iter [150/418], Loss: total=2.304, reg=13.731, containing_obj=8.118, no_obj=2.138, cls=3.661
# Epoch [23/50], Iter [200/418], Loss: total=2.312, reg=13.882, containing_obj=8.121, no_obj=2.149, cls=3.598
# Epoch [23/50], Iter [250/418], Loss: total=2.290, reg=13.787, containing_obj=8.020, no_obj=2.123, cls=3.548
# Epoch [23/50], Iter [300/418], Loss: total=2.274, reg=13.673, containing_obj=7.960, no_obj=2.122, cls=3.539
# Epoch [23/50], Iter [350/418], Loss: total=2.250, reg=13.595, containing_obj=7.834, no_obj=2.110, cls=3.465
# Epoch [23/50], Iter [400/418], Loss: total=2.245, reg=13.602, containing_obj=7.826, no_obj=2.094, cls=3.424
#
#
# Starting epoch 24 / 50
# Learning Rate for this epoch: 0.001
# Epoch [24/50], Iter [50/418], Loss: total=2.189, reg=12.830, containing_obj=7.882, no_obj=2.080, cls=3.474
# Epoch [24/50], Iter [100/418], Loss: total=2.183, reg=12.855, containing_obj=7.793, no_obj=2.122, cls=3.428
# Epoch [24/50], Iter [150/418], Loss: total=2.190, reg=12.946, containing_obj=7.809, no_obj=2.104, cls=3.419
# Epoch [24/50], Iter [200/418], Loss: total=2.208, reg=13.174, containing_obj=7.881, no_obj=2.136, cls=3.307
# Epoch [24/50], Iter [250/418], Loss: total=2.198, reg=13.088, containing_obj=7.802, no_obj=2.130, cls=3.362
# Epoch [24/50], Iter [300/418], Loss: total=2.229, reg=13.339, containing_obj=7.878, no_obj=2.131, cls=3.404
# Epoch [24/50], Iter [350/418], Loss: total=2.224, reg=13.325, containing_obj=7.853, no_obj=2.128, cls=3.384
# Epoch [24/50], Iter [400/418], Loss: total=2.216, reg=13.290, containing_obj=7.809, no_obj=2.144, cls=3.354
# Updating best test loss: 2.65599
#
#
# Starting epoch 25 / 50
# Learning Rate for this epoch: 0.001
# Epoch [25/50], Iter [50/418], Loss: total=2.175, reg=13.433, containing_obj=7.328, no_obj=2.118, cls=3.218
# Epoch [25/50], Iter [100/418], Loss: total=2.166, reg=13.238, containing_obj=7.468, no_obj=2.052, cls=3.238
# Epoch [25/50], Iter [150/418], Loss: total=2.234, reg=13.555, containing_obj=7.812, no_obj=2.055, cls=3.389
# Epoch [25/50], Iter [200/418], Loss: total=2.213, reg=13.433, containing_obj=7.685, no_obj=2.113, cls=3.320
# Epoch [25/50], Iter [250/418], Loss: total=2.248, reg=13.677, containing_obj=7.834, no_obj=2.099, cls=3.371
# Epoch [25/50], Iter [300/418], Loss: total=2.229, reg=13.515, containing_obj=7.796, no_obj=2.114, cls=3.320
# Epoch [25/50], Iter [350/418], Loss: total=2.230, reg=13.537, containing_obj=7.818, no_obj=2.114, cls=3.291
# Epoch [25/50], Iter [400/418], Loss: total=2.220, reg=13.449, containing_obj=7.795, no_obj=2.101, cls=3.300
# ---Evaluate model on test samples---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [01:01<00:00, 80.69it/s]
# ---class aeroplane ap 0.4849797428113236---
# ---class bicycle ap 0.6564116469619934---
# ---class bird ap 0.5191763297464278---
# ---class boat ap 0.26905597661644576---
# ---class bottle ap 0.14207175287913884---
# ---class bus ap 0.6234274499174581---
# ---class car ap 0.6502019135085312---
# ---class cat ap 0.6525699108401215---
# ---class chair ap 0.2536852826485523---
# ---class cow ap 0.4119227521523049---
# ---class diningtable ap 0.21156810768271705---
# ---class dog ap 0.6113964915627601---
# ---class horse ap 0.6116403896626141---
# ---class motorbike ap 0.5775591801164295---
# ---class person ap 0.49976891930072953---
# ---class pottedplant ap 0.16728526809772976---
# ---class sheep ap 0.4619996779243573---
# ---class sofa ap 0.43488763336625047---
# ---class train ap 0.6618021501590492---
# ---class tvmonitor ap 0.4653374401425878---
# ---map 0.46833740080487607---
# 24 [np.float64(0.4849797428113236), np.float64(0.6564116469619934), np.float64(0.5191763297464278), np.float64(0.26905597661644576), np.float64(0.14207175287913884), np.float64(0.6234274499174581), np.float64(0.6502019135085312), np.float64(0.6525699108401215), np.float64(0.2536852826485523), np.float64(0.4119227521523049), np.float64(0.21156810768271705), np.float64(0.6113964915627601), np.float64(0.6116403896626141), np.float64(0.5775591801164295), np.float64(0.49976891930072953), np.float64(0.16728526809772976), np.float64(0.4619996779243573), np.float64(0.43488763336625047), np.float64(0.6618021501590492), np.float64(0.4653374401425878)]
# Updating best test loss: 2.64797
#
#
# Starting epoch 26 / 50
# Learning Rate for this epoch: 0.001
# Epoch [26/50], Iter [50/418], Loss: total=2.360, reg=14.630, containing_obj=8.085, no_obj=2.113, cls=3.496
# Epoch [26/50], Iter [100/418], Loss: total=2.227, reg=13.612, containing_obj=7.788, no_obj=2.173, cls=3.153
# Epoch [26/50], Iter [150/418], Loss: total=2.201, reg=13.270, containing_obj=7.763, no_obj=2.206, cls=3.168
# Epoch [26/50], Iter [200/418], Loss: total=2.170, reg=13.066, containing_obj=7.599, no_obj=2.212, cls=3.166
# Epoch [26/50], Iter [250/418], Loss: total=2.187, reg=13.200, containing_obj=7.705, no_obj=2.181, cls=3.157
# Epoch [26/50], Iter [300/418], Loss: total=2.176, reg=13.132, containing_obj=7.627, no_obj=2.182, cls=3.171
# Epoch [26/50], Iter [350/418], Loss: total=2.178, reg=13.173, containing_obj=7.630, no_obj=2.170, cls=3.160
# Epoch [26/50], Iter [400/418], Loss: total=2.179, reg=13.163, containing_obj=7.629, no_obj=2.163, cls=3.190
#
#
# Starting epoch 27 / 50
# Learning Rate for this epoch: 0.001
# Epoch [27/50], Iter [50/418], Loss: total=2.137, reg=13.417, containing_obj=7.470, no_obj=2.181, cls=2.571
# Epoch [27/50], Iter [100/418], Loss: total=2.170, reg=13.459, containing_obj=7.633, no_obj=2.218, cls=2.724
# Epoch [27/50], Iter [150/418], Loss: total=2.136, reg=13.040, containing_obj=7.547, no_obj=2.213, cls=2.829
# Epoch [27/50], Iter [200/418], Loss: total=2.147, reg=13.051, containing_obj=7.636, no_obj=2.183, cls=2.895
# Epoch [27/50], Iter [250/418], Loss: total=2.153, reg=13.050, containing_obj=7.688, no_obj=2.179, cls=2.923
# Epoch [27/50], Iter [300/418], Loss: total=2.166, reg=13.150, containing_obj=7.732, no_obj=2.168, cls=2.945
# Epoch [27/50], Iter [350/418], Loss: total=2.171, reg=13.154, containing_obj=7.693, no_obj=2.180, cls=3.021
# Epoch [27/50], Iter [400/418], Loss: total=2.169, reg=13.116, containing_obj=7.713, no_obj=2.180, cls=3.015
# Updating best test loss: 2.63234
#
#
# Starting epoch 28 / 50
# Learning Rate for this epoch: 0.001
# Epoch [28/50], Iter [50/418], Loss: total=2.131, reg=12.601, containing_obj=7.898, no_obj=2.190, cls=2.884
# Epoch [28/50], Iter [100/418], Loss: total=2.143, reg=12.755, containing_obj=7.988, no_obj=2.170, cls=2.801
# Epoch [28/50], Iter [150/418], Loss: total=2.159, reg=12.822, containing_obj=7.913, no_obj=2.227, cls=2.942
# Epoch [28/50], Iter [200/418], Loss: total=2.130, reg=12.699, containing_obj=7.764, no_obj=2.193, cls=2.903
# Epoch [28/50], Iter [250/418], Loss: total=2.137, reg=12.753, containing_obj=7.714, no_obj=2.203, cls=2.970
# Epoch [28/50], Iter [300/418], Loss: total=2.131, reg=12.736, containing_obj=7.678, no_obj=2.204, cls=2.955
# Epoch [28/50], Iter [350/418], Loss: total=2.131, reg=12.703, containing_obj=7.713, no_obj=2.189, cls=2.965
# Epoch [28/50], Iter [400/418], Loss: total=2.107, reg=12.568, containing_obj=7.622, no_obj=2.189, cls=2.910
#
#
# Starting epoch 29 / 50
# Learning Rate for this epoch: 0.001
# Epoch [29/50], Iter [50/418], Loss: total=1.992, reg=12.005, containing_obj=7.182, no_obj=2.219, cls=2.495
# Epoch [29/50], Iter [100/418], Loss: total=2.019, reg=12.053, containing_obj=7.268, no_obj=2.207, cls=2.697
# Epoch [29/50], Iter [150/418], Loss: total=2.060, reg=12.263, containing_obj=7.472, no_obj=2.183, cls=2.796
# Epoch [29/50], Iter [200/418], Loss: total=2.060, reg=12.313, containing_obj=7.486, no_obj=2.178, cls=2.747
# Epoch [29/50], Iter [250/418], Loss: total=2.080, reg=12.505, containing_obj=7.469, no_obj=2.172, cls=2.813
# Epoch [29/50], Iter [300/418], Loss: total=2.086, reg=12.508, containing_obj=7.509, no_obj=2.203, cls=2.807
# Epoch [29/50], Iter [350/418], Loss: total=2.078, reg=12.401, containing_obj=7.512, no_obj=2.207, cls=2.812
# Epoch [29/50], Iter [400/418], Loss: total=2.074, reg=12.371, containing_obj=7.540, no_obj=2.214, cls=2.764
# Updating best test loss: 2.62834
#
#
# Starting epoch 30 / 50
# Learning Rate for this epoch: 0.001
# Epoch [30/50], Iter [50/418], Loss: total=2.061, reg=12.532, containing_obj=7.383, no_obj=2.085, cls=2.731
# Epoch [30/50], Iter [100/418], Loss: total=2.078, reg=12.385, containing_obj=7.759, no_obj=2.132, cls=2.657
# Epoch [30/50], Iter [150/418], Loss: total=2.040, reg=11.988, containing_obj=7.629, no_obj=2.208, cls=2.649
# Epoch [30/50], Iter [200/418], Loss: total=2.051, reg=12.108, containing_obj=7.645, no_obj=2.221, cls=2.635
# Epoch [30/50], Iter [250/418], Loss: total=2.088, reg=12.448, containing_obj=7.662, no_obj=2.215, cls=2.725
# Epoch [30/50], Iter [300/418], Loss: total=2.095, reg=12.475, containing_obj=7.679, no_obj=2.216, cls=2.773
# Epoch [30/50], Iter [350/418], Loss: total=2.105, reg=12.542, containing_obj=7.683, no_obj=2.211, cls=2.823
# Epoch [30/50], Iter [400/418], Loss: total=2.087, reg=12.383, containing_obj=7.626, no_obj=2.216, cls=2.824
# ---Evaluate model on test samples---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [01:01<00:00, 80.91it/s]
# ---class aeroplane ap 0.49365909436860317---
# ---class bicycle ap 0.6173733117719948---
# ---class bird ap 0.47822380673038556---
# ---class boat ap 0.24777198705293527---
# ---class bottle ap 0.20670031068367786---
# ---class bus ap 0.6281217429323155---
# ---class car ap 0.5975602967959956---
# ---class cat ap 0.7375403652866828---
# ---class chair ap 0.28072183378769666---
# ---class cow ap 0.4518371189629482---
# ---class diningtable ap 0.28935111946845177---
# ---class dog ap 0.6421199345493434---
# ---class horse ap 0.6572141001607116---
# ---class motorbike ap 0.5713384414006486---
# ---class person ap 0.5074463424643786---
# ---class pottedplant ap 0.22345865635442957---
# ---class sheep ap 0.4761986751936339---
# ---class sofa ap 0.4040243445899557---
# ---class train ap 0.6411233717477263---
# ---class tvmonitor ap 0.5094504453118228---
# ---map 0.4830617649807169---
# 29 [np.float64(0.49365909436860317), np.float64(0.6173733117719948), np.float64(0.47822380673038556), np.float64(0.24777198705293527), np.float64(0.20670031068367786), np.float64(0.6281217429323155), np.float64(0.5975602967959956), np.float64(0.7375403652866828), np.float64(0.28072183378769666), np.float64(0.4518371189629482), np.float64(0.28935111946845177), np.float64(0.6421199345493434), np.float64(0.6572141001607116), np.float64(0.5713384414006486), np.float64(0.5074463424643786), np.float64(0.22345865635442957), np.float64(0.4761986751936339), np.float64(0.4040243445899557), np.float64(0.6411233717477263), np.float64(0.5094504453118228)]
# Updating best test loss: 2.57448
#
#
# Starting epoch 31 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [31/50], Iter [50/418], Loss: total=2.037, reg=12.406, containing_obj=7.661, no_obj=1.997, cls=2.379
# Epoch [31/50], Iter [100/418], Loss: total=2.025, reg=12.194, containing_obj=7.564, no_obj=2.069, cls=2.470
# Epoch [31/50], Iter [150/418], Loss: total=2.035, reg=12.240, containing_obj=7.614, no_obj=2.099, cls=2.466
# Epoch [31/50], Iter [200/418], Loss: total=2.003, reg=11.945, containing_obj=7.501, no_obj=2.101, cls=2.493
# Epoch [31/50], Iter [250/418], Loss: total=2.009, reg=11.933, containing_obj=7.529, no_obj=2.115, cls=2.529
# Epoch [31/50], Iter [300/418], Loss: total=1.993, reg=11.841, containing_obj=7.459, no_obj=2.128, cls=2.483
# Epoch [31/50], Iter [350/418], Loss: total=1.997, reg=11.831, containing_obj=7.493, no_obj=2.138, cls=2.502
# Epoch [31/50], Iter [400/418], Loss: total=2.001, reg=11.834, containing_obj=7.540, no_obj=2.141, cls=2.503
# Updating best test loss: 2.54688
#
#
# Starting epoch 32 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [32/50], Iter [50/418], Loss: total=1.965, reg=11.299, containing_obj=7.300, no_obj=2.301, cls=2.681
# Epoch [32/50], Iter [100/418], Loss: total=1.988, reg=11.608, containing_obj=7.487, no_obj=2.212, cls=2.545
# Epoch [32/50], Iter [150/418], Loss: total=2.018, reg=11.949, containing_obj=7.518, no_obj=2.207, cls=2.542
# Epoch [32/50], Iter [200/418], Loss: total=1.954, reg=11.483, containing_obj=7.301, no_obj=2.245, cls=2.414
# Epoch [32/50], Iter [250/418], Loss: total=1.965, reg=11.486, containing_obj=7.382, no_obj=2.253, cls=2.457
# Epoch [32/50], Iter [300/418], Loss: total=1.953, reg=11.477, containing_obj=7.281, no_obj=2.248, cls=2.431
# Epoch [32/50], Iter [350/418], Loss: total=1.939, reg=11.375, containing_obj=7.207, no_obj=2.255, cls=2.428
# Epoch [32/50], Iter [400/418], Loss: total=1.946, reg=11.460, containing_obj=7.222, no_obj=2.245, cls=2.420
# Updating best test loss: 2.53025
#
#
# Starting epoch 33 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [33/50], Iter [50/418], Loss: total=1.848, reg=10.728, containing_obj=6.895, no_obj=2.290, cls=2.263
# Epoch [33/50], Iter [100/418], Loss: total=1.882, reg=11.002, containing_obj=6.969, no_obj=2.278, cls=2.336
# Epoch [33/50], Iter [150/418], Loss: total=1.911, reg=11.291, containing_obj=7.137, no_obj=2.246, cls=2.264
# Epoch [33/50], Iter [200/418], Loss: total=1.923, reg=11.312, containing_obj=7.227, no_obj=2.250, cls=2.286
# Epoch [33/50], Iter [250/418], Loss: total=1.958, reg=11.508, containing_obj=7.337, no_obj=2.240, cls=2.412
# Epoch [33/50], Iter [300/418], Loss: total=1.949, reg=11.426, containing_obj=7.324, no_obj=2.257, cls=2.386
# Epoch [33/50], Iter [350/418], Loss: total=1.955, reg=11.448, containing_obj=7.376, no_obj=2.251, cls=2.386
# Epoch [33/50], Iter [400/418], Loss: total=1.956, reg=11.425, containing_obj=7.356, no_obj=2.259, cls=2.435
#
#
# Starting epoch 34 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [34/50], Iter [50/418], Loss: total=2.048, reg=12.044, containing_obj=7.827, no_obj=2.163, cls=2.541
# Epoch [34/50], Iter [100/418], Loss: total=1.995, reg=11.564, containing_obj=7.642, no_obj=2.186, cls=2.544
# Epoch [34/50], Iter [150/418], Loss: total=1.970, reg=11.388, containing_obj=7.442, no_obj=2.228, cls=2.584
# Epoch [34/50], Iter [200/418], Loss: total=1.971, reg=11.400, containing_obj=7.478, no_obj=2.235, cls=2.537
# Epoch [34/50], Iter [250/418], Loss: total=1.974, reg=11.538, containing_obj=7.409, no_obj=2.235, cls=2.512
# Epoch [34/50], Iter [300/418], Loss: total=1.956, reg=11.463, containing_obj=7.307, no_obj=2.248, cls=2.452
# Epoch [34/50], Iter [350/418], Loss: total=1.944, reg=11.472, containing_obj=7.263, no_obj=2.243, cls=2.356
# Epoch [34/50], Iter [400/418], Loss: total=1.930, reg=11.370, containing_obj=7.206, no_obj=2.252, cls=2.337
# Updating best test loss: 2.52773
#
#
# Starting epoch 35 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [35/50], Iter [50/418], Loss: total=1.963, reg=11.719, containing_obj=7.348, no_obj=2.298, cls=2.192
# Epoch [35/50], Iter [100/418], Loss: total=2.023, reg=11.817, containing_obj=7.751, no_obj=2.245, cls=2.460
# Epoch [35/50], Iter [150/418], Loss: total=1.986, reg=11.592, containing_obj=7.678, no_obj=2.246, cls=2.320
# Epoch [35/50], Iter [200/418], Loss: total=1.989, reg=11.583, containing_obj=7.637, no_obj=2.271, cls=2.382
# Epoch [35/50], Iter [250/418], Loss: total=1.969, reg=11.480, containing_obj=7.495, no_obj=2.282, cls=2.376
# Epoch [35/50], Iter [300/418], Loss: total=1.959, reg=11.435, containing_obj=7.439, no_obj=2.275, cls=2.359
# Epoch [35/50], Iter [350/418], Loss: total=1.942, reg=11.288, containing_obj=7.402, no_obj=2.279, cls=2.340
# Epoch [35/50], Iter [400/418], Loss: total=1.933, reg=11.263, containing_obj=7.330, no_obj=2.284, cls=2.320
# ---Evaluate model on test samples---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [01:06<00:00, 74.40it/s]
# ---class aeroplane ap 0.522736248607764---
# ---class bicycle ap 0.6752918334070963---
# ---class bird ap 0.49871074051901854---
# ---class boat ap 0.30431296636940064---
# ---class bottle ap 0.1661813405022119---
# ---class bus ap 0.6270688641812698---
# ---class car ap 0.6182094517500981---
# ---class cat ap 0.7139271044420465---
# ---class chair ap 0.296195938140271---
# ---class cow ap 0.49185475572895493---
# ---class diningtable ap 0.3135441754725441---
# ---class dog ap 0.6709294329428412---
# ---class horse ap 0.6923532241106122---
# ---class motorbike ap 0.5562543868667456---
# ---class person ap 0.48181699279640455---
# ---class pottedplant ap 0.22053556793629603---
# ---class sheep ap 0.5046405598232726---
# ---class sofa ap 0.45381076796397335---
# ---class train ap 0.663735714615626---
# ---class tvmonitor ap 0.5121942800741646---
# ---map 0.4992152173125306---
# 34 [np.float64(0.522736248607764), np.float64(0.6752918334070963), np.float64(0.49871074051901854), np.float64(0.30431296636940064), np.float64(0.1661813405022119), np.float64(0.6270688641812698), np.float64(0.6182094517500981), np.float64(0.7139271044420465), np.float64(0.296195938140271), np.float64(0.49185475572895493), np.float64(0.3135441754725441), np.float64(0.6709294329428412), np.float64(0.6923532241106122), np.float64(0.5562543868667456), np.float64(0.48181699279640455), np.float64(0.22053556793629603), np.float64(0.5046405598232726), np.float64(0.45381076796397335), np.float64(0.663735714615626), np.float64(0.5121942800741646)]
# Updating best test loss: 2.52425
#
#
# Starting epoch 36 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [36/50], Iter [50/418], Loss: total=1.869, reg=10.661, containing_obj=7.232, no_obj=2.343, cls=2.188
# Epoch [36/50], Iter [100/418], Loss: total=1.885, reg=10.871, containing_obj=7.119, no_obj=2.350, cls=2.277
# Epoch [36/50], Iter [150/418], Loss: total=1.870, reg=10.977, containing_obj=6.997, no_obj=2.295, cls=2.168
# Epoch [36/50], Iter [200/418], Loss: total=1.880, reg=11.085, containing_obj=7.047, no_obj=2.282, cls=2.150
# Epoch [36/50], Iter [250/418], Loss: total=1.884, reg=11.114, containing_obj=7.034, no_obj=2.274, cls=2.188
# Epoch [36/50], Iter [300/418], Loss: total=1.892, reg=11.135, containing_obj=7.077, no_obj=2.260, cls=2.236
# Epoch [36/50], Iter [350/418], Loss: total=1.896, reg=11.140, containing_obj=7.098, no_obj=2.273, cls=2.247
# Epoch [36/50], Iter [400/418], Loss: total=1.907, reg=11.207, containing_obj=7.140, no_obj=2.269, cls=2.262
# Updating best test loss: 2.52288
#
#
# Starting epoch 37 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [37/50], Iter [50/418], Loss: total=2.014, reg=12.068, containing_obj=7.517, no_obj=2.161, cls=2.428
# Epoch [37/50], Iter [100/418], Loss: total=1.926, reg=11.435, containing_obj=7.313, no_obj=2.217, cls=2.145
# Epoch [37/50], Iter [150/418], Loss: total=1.911, reg=11.271, containing_obj=7.182, no_obj=2.253, cls=2.220
# Epoch [37/50], Iter [200/418], Loss: total=1.912, reg=11.217, containing_obj=7.184, no_obj=2.275, cls=2.271
# Epoch [37/50], Iter [250/418], Loss: total=1.904, reg=11.226, containing_obj=7.117, no_obj=2.271, cls=2.230
# Epoch [37/50], Iter [300/418], Loss: total=1.897, reg=11.196, containing_obj=7.073, no_obj=2.271, cls=2.228
# Epoch [37/50], Iter [350/418], Loss: total=1.907, reg=11.257, containing_obj=7.128, no_obj=2.261, cls=2.239
# Epoch [37/50], Iter [400/418], Loss: total=1.900, reg=11.220, containing_obj=7.114, no_obj=2.250, cls=2.214
# Updating best test loss: 2.51163
#
#
# Starting epoch 38 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [38/50], Iter [50/418], Loss: total=1.856, reg=10.632, containing_obj=7.287, no_obj=2.345, cls=2.010
# Epoch [38/50], Iter [100/418], Loss: total=1.874, reg=10.678, containing_obj=7.299, no_obj=2.328, cls=2.189
# Epoch [38/50], Iter [150/418], Loss: total=1.873, reg=10.838, containing_obj=7.146, no_obj=2.290, cls=2.208
# Epoch [38/50], Iter [200/418], Loss: total=1.850, reg=10.732, containing_obj=7.063, no_obj=2.285, cls=2.124
# Epoch [38/50], Iter [250/418], Loss: total=1.901, reg=11.072, containing_obj=7.215, no_obj=2.278, cls=2.247
# Epoch [38/50], Iter [300/418], Loss: total=1.911, reg=11.158, containing_obj=7.202, no_obj=2.285, cls=2.282
# ...
# Epoch [39/50], Iter [200/418], Loss: total=1.865, reg=10.762, containing_obj=7.097, no_obj=2.302, cls=2.217
# Epoch [39/50], Iter [250/418], Loss: total=1.883, reg=10.895, containing_obj=7.219, no_obj=2.279, cls=2.207
# Epoch [39/50], Iter [300/418], Loss: total=1.866, reg=10.813, containing_obj=7.104, no_obj=2.287, cls=2.186
# Epoch [39/50], Iter [350/418], Loss: total=1.858, reg=10.754, containing_obj=7.058, no_obj=2.307, cls=2.180
# Epoch [39/50], Iter [400/418], Loss: total=1.875, reg=10.876, containing_obj=7.082, no_obj=2.303, cls=2.243
# Updating best test loss: 2.51057
#
#
# Starting epoch 40 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [40/50], Iter [50/418], Loss: total=1.862, reg=10.770, containing_obj=7.281, no_obj=2.161, cls=2.137
# Epoch [40/50], Iter [100/418], Loss: total=1.891, reg=11.068, containing_obj=7.200, no_obj=2.231, cls=2.199
# Epoch [40/50], Iter [150/418], Loss: total=1.879, reg=11.048, containing_obj=7.080, no_obj=2.252, cls=2.166
# Epoch [40/50], Iter [200/418], Loss: total=1.860, reg=10.974, containing_obj=6.891, no_obj=2.299, cls=2.154
# Epoch [40/50], Iter [250/418], Loss: total=1.854, reg=10.935, containing_obj=6.901, no_obj=2.281, cls=2.131
# Epoch [40/50], Iter [300/418], Loss: total=1.851, reg=10.819, containing_obj=6.934, no_obj=2.281, cls=2.179
# Epoch [40/50], Iter [350/418], Loss: total=1.849, reg=10.789, containing_obj=6.920, no_obj=2.271, cls=2.209
# Epoch [40/50], Iter [400/418], Loss: total=1.854, reg=10.810, containing_obj=6.950, no_obj=2.276, cls=2.208
# ---Evaluate model on test samples---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [01:01<00:00, 79.96it/s]
# ---class aeroplane ap 0.5043034184702642---
# ---class bicycle ap 0.6731574703273904---
# ---class bird ap 0.4989357363109963---
# ---class boat ap 0.3151889286545504---
# ---class bottle ap 0.20254852425389352---
# ---class bus ap 0.6170274309879066---
# ---class car ap 0.6660200412955556---
# ---class cat ap 0.7168461337468057---
# ---class chair ap 0.30945530872993343---
# ---class cow ap 0.4992876671388011---
# ---class diningtable ap 0.33674424491949745---
# ---class dog ap 0.675496834693018---
# ---class horse ap 0.6865474576257347---
# ---class motorbike ap 0.6083418412554314---
# ---class person ap 0.5118856074194587---
# ---class pottedplant ap 0.2474946920371196---
# ---class sheep ap 0.5124764890474487---
# ---class sofa ap 0.4884130545659859---
# ---class train ap 0.6644140023752985---
# ---class tvmonitor ap 0.5165621655947288---
# ---map 0.512557352472491---
# 39 [np.float64(0.5043034184702642), np.float64(0.6731574703273904), np.float64(0.4989357363109963), np.float64(0.3151889286545504), np.float64(0.20254852425389352), np.float64(0.6170274309879066), np.float64(0.6660200412955556), np.float64(0.7168461337468057), np.float64(0.30945530872993343), np.float64(0.4992876671388011), np.float64(0.33674424491949745), np.float64(0.675496834693018), np.float64(0.6865474576257347), np.float64(0.6083418412554314), np.float64(0.5118856074194587), np.float64(0.2474946920371196), np.float64(0.5124764890474487), np.float64(0.4884130545659859), np.float64(0.6644140023752985), np.float64(0.5165621655947288)]
#
#
# Starting epoch 41 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [41/50], Iter [50/418], Loss: total=1.797, reg=10.369, containing_obj=6.911, no_obj=2.335, cls=1.954
# Epoch [41/50], Iter [100/418], Loss: total=1.843, reg=10.595, containing_obj=7.091, no_obj=2.316, cls=2.112
# Epoch [41/50], Iter [150/418], Loss: total=1.869, reg=10.796, containing_obj=7.158, no_obj=2.299, cls=2.182
# Epoch [41/50], Iter [200/418], Loss: total=1.883, reg=10.876, containing_obj=7.228, no_obj=2.288, cls=2.204
# Epoch [41/50], Iter [250/418], Loss: total=1.898, reg=11.026, containing_obj=7.250, no_obj=2.302, cls=2.193
# Epoch [41/50], Iter [300/418], Loss: total=1.898, reg=11.090, containing_obj=7.211, no_obj=2.308, cls=2.170
# Epoch [41/50], Iter [350/418], Loss: total=1.900, reg=11.117, containing_obj=7.234, no_obj=2.295, cls=2.156
# Epoch [41/50], Iter [400/418], Loss: total=1.884, reg=11.071, containing_obj=7.147, no_obj=2.284, cls=2.109
#
#
# Starting epoch 42 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [42/50], Iter [50/418], Loss: total=1.889, reg=11.350, containing_obj=6.849, no_obj=2.202, cls=2.264
# Epoch [42/50], Iter [100/418], Loss: total=1.852, reg=10.957, containing_obj=6.928, no_obj=2.218, cls=2.115
# Epoch [42/50], Iter [150/418], Loss: total=1.846, reg=10.608, containing_obj=7.090, no_obj=2.276, cls=2.171
# Epoch [42/50], Iter [200/418], Loss: total=1.887, reg=10.961, containing_obj=7.186, no_obj=2.295, cls=2.203
# Epoch [42/50], Iter [250/418], Loss: total=1.876, reg=10.883, containing_obj=7.147, no_obj=2.283, cls=2.199
# Epoch [42/50], Iter [300/418], Loss: total=1.879, reg=10.904, containing_obj=7.132, no_obj=2.301, cls=2.211
# Epoch [42/50], Iter [350/418], Loss: total=1.866, reg=10.827, containing_obj=7.081, no_obj=2.313, cls=2.173
# Epoch [42/50], Iter [400/418], Loss: total=1.875, reg=10.922, containing_obj=7.071, no_obj=2.318, cls=2.192
# Updating best test loss: 2.50344
#
#
# Starting epoch 43 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [43/50], Iter [50/418], Loss: total=1.737, reg=9.964, containing_obj=6.672, no_obj=2.413, cls=1.797
# Epoch [43/50], Iter [100/418], Loss: total=1.786, reg=10.188, containing_obj=6.844, no_obj=2.349, cls=2.053
# Epoch [43/50], Iter [150/418], Loss: total=1.841, reg=10.588, containing_obj=6.977, no_obj=2.305, cls=2.226
# Epoch [43/50], Iter [200/418], Loss: total=1.872, reg=10.807, containing_obj=7.024, no_obj=2.331, cls=2.298
# Epoch [43/50], Iter [250/418], Loss: total=1.891, reg=11.015, containing_obj=7.088, no_obj=2.304, cls=2.285
# Epoch [43/50], Iter [300/418], Loss: total=1.874, reg=10.897, containing_obj=7.031, no_obj=2.317, cls=2.239
# Epoch [43/50], Iter [350/418], Loss: total=1.889, reg=11.059, containing_obj=7.067, no_obj=2.307, cls=2.234
# Epoch [43/50], Iter [400/418], Loss: total=1.902, reg=11.158, containing_obj=7.120, no_obj=2.291, cls=2.260
#
#
# Starting epoch 44 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [44/50], Iter [50/418], Loss: total=1.904, reg=11.074, containing_obj=7.593, no_obj=2.169, cls=2.009
# Epoch [44/50], Iter [100/418], Loss: total=1.888, reg=11.088, containing_obj=7.388, no_obj=2.197, cls=1.979
# Epoch [44/50], Iter [150/418], Loss: total=1.884, reg=10.966, containing_obj=7.339, no_obj=2.258, cls=2.040
# Epoch [44/50], Iter [200/418], Loss: total=1.906, reg=11.203, containing_obj=7.329, no_obj=2.263, cls=2.075
# Epoch [44/50], Iter [250/418], Loss: total=1.887, reg=11.135, containing_obj=7.200, no_obj=2.262, cls=2.053
# Epoch [44/50], Iter [300/418], Loss: total=1.867, reg=10.991, containing_obj=7.122, no_obj=2.277, cls=2.010
# Epoch [44/50], Iter [350/418], Loss: total=1.858, reg=10.882, containing_obj=7.119, no_obj=2.290, cls=2.000
# Epoch [44/50], Iter [400/418], Loss: total=1.872, reg=11.008, containing_obj=7.112, no_obj=2.291, cls=2.057
#
#
# Starting epoch 45 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [45/50], Iter [50/418], Loss: total=1.973, reg=11.647, containing_obj=7.587, no_obj=2.197, cls=2.239
# Epoch [45/50], Iter [100/418], Loss: total=1.932, reg=11.254, containing_obj=7.256, no_obj=2.339, cls=2.340
# Epoch [45/50], Iter [150/418], Loss: total=1.893, reg=10.902, containing_obj=7.206, no_obj=2.331, cls=2.281
# Epoch [45/50], Iter [200/418], Loss: total=1.895, reg=11.011, containing_obj=7.126, no_obj=2.339, cls=2.265
# Epoch [45/50], Iter [250/418], Loss: total=1.896, reg=11.114, containing_obj=7.088, no_obj=2.323, cls=2.221
# Epoch [45/50], Iter [300/418], Loss: total=1.898, reg=11.184, containing_obj=7.080, no_obj=2.314, cls=2.203
# Epoch [45/50], Iter [350/418], Loss: total=1.904, reg=11.208, containing_obj=7.131, no_obj=2.297, cls=2.212
# Epoch [45/50], Iter [400/418], Loss: total=1.882, reg=11.014, containing_obj=7.069, no_obj=2.315, cls=2.186
# ---Evaluate model on test samples---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [01:02<00:00, 79.58it/s]
# ---class aeroplane ap 0.4912105201903013---
# ---class bicycle ap 0.6689621822495608---
# ---class bird ap 0.4968668401091273---
# ---class boat ap 0.3359744325973809---
# ---class bottle ap 0.19360070606661617---
# ---class bus ap 0.6386429605856626---
# ---class car ap 0.6595850749741636---
# ---class cat ap 0.7339449690314916---
# ---class chair ap 0.3159464270480459---
# ---class cow ap 0.5271128533637269---
# ---class diningtable ap 0.3626931538493996---
# ---class dog ap 0.6619527402334309---
# ---class horse ap 0.6942485713413951---
# ---class motorbike ap 0.6072626646430932---
# ---class person ap 0.49818483632302146---
# ---class pottedplant ap 0.23956197746884794---
# ---class sheep ap 0.5115733931414324---
# ---class sofa ap 0.49994898741415084---
# ---class train ap 0.6789390737835967---
# ---class tvmonitor ap 0.5185792443746275---
# ---map 0.5167395804394536---
# 44 [np.float64(0.4912105201903013), np.float64(0.6689621822495608), np.float64(0.4968668401091273), np.float64(0.3359744325973809), np.float64(0.19360070606661617), np.float64(0.6386429605856626), np.float64(0.6595850749741636), np.float64(0.7339449690314916), np.float64(0.3159464270480459), np.float64(0.5271128533637269), np.float64(0.3626931538493996), np.float64(0.6619527402334309), np.float64(0.6942485713413951), np.float64(0.6072626646430932), np.float64(0.49818483632302146), np.float64(0.23956197746884794), np.float64(0.5115733931414324), np.float64(0.49994898741415084), np.float64(0.6789390737835967), np.float64(0.5185792443746275)]
#
#
# Starting epoch 46 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [46/50], Iter [50/418], Loss: total=1.847, reg=10.865, containing_obj=7.137, no_obj=2.270, cls=1.895
# Epoch [46/50], Iter [100/418], Loss: total=1.806, reg=10.521, containing_obj=6.898, no_obj=2.295, cls=1.953
# Epoch [46/50], Iter [150/418], Loss: total=1.844, reg=10.801, containing_obj=7.028, no_obj=2.298, cls=2.004
# Epoch [46/50], Iter [200/418], Loss: total=1.808, reg=10.482, containing_obj=6.937, no_obj=2.298, cls=1.985
# Epoch [46/50], Iter [250/418], Loss: total=1.810, reg=10.430, containing_obj=6.968, no_obj=2.310, cls=2.009
# Epoch [46/50], Iter [300/418], Loss: total=1.852, reg=10.771, containing_obj=7.092, no_obj=2.292, cls=2.074
# Epoch [46/50], Iter [350/418], Loss: total=1.864, reg=10.874, containing_obj=7.110, no_obj=2.302, cls=2.082
# Epoch [46/50], Iter [400/418], Loss: total=1.877, reg=10.973, containing_obj=7.123, no_obj=2.300, cls=2.133
#
#
# Starting epoch 47 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [47/50], Iter [50/418], Loss: total=1.859, reg=10.927, containing_obj=7.004, no_obj=2.224, cls=2.158
# Epoch [47/50], Iter [100/418], Loss: total=1.845, reg=10.845, containing_obj=6.957, no_obj=2.257, cls=2.082
# Epoch [47/50], Iter [150/418], Loss: total=1.863, reg=10.921, containing_obj=6.992, no_obj=2.237, cls=2.209
# Epoch [47/50], Iter [200/418], Loss: total=1.858, reg=10.881, containing_obj=6.983, no_obj=2.234, cls=2.204
# Epoch [47/50], Iter [250/418], Loss: total=1.850, reg=10.787, containing_obj=6.992, no_obj=2.266, cls=2.160
# Epoch [47/50], Iter [300/418], Loss: total=1.837, reg=10.666, containing_obj=6.954, no_obj=2.256, cls=2.166
# Epoch [47/50], Iter [350/418], Loss: total=1.861, reg=10.815, containing_obj=7.049, no_obj=2.265, cls=2.202
# Epoch [47/50], Iter [400/418], Loss: total=1.869, reg=10.849, containing_obj=7.094, no_obj=2.260, cls=2.224
# Updating best test loss: 2.49905
#
#
# Starting epoch 48 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [48/50], Iter [50/418], Loss: total=1.893, reg=11.181, containing_obj=7.251, no_obj=2.258, cls=2.025
# Epoch [48/50], Iter [100/418], Loss: total=1.932, reg=11.430, containing_obj=7.376, no_obj=2.269, cls=2.105
# Epoch [48/50], Iter [150/418], Loss: total=1.893, reg=11.053, containing_obj=7.228, no_obj=2.329, cls=2.101
# Epoch [48/50], Iter [200/418], Loss: total=1.922, reg=11.212, containing_obj=7.386, no_obj=2.310, cls=2.156
# Epoch [48/50], Iter [250/418], Loss: total=1.911, reg=11.095, containing_obj=7.298, no_obj=2.315, cls=2.221
# Epoch [48/50], Iter [300/418], Loss: total=1.892, reg=10.947, containing_obj=7.233, no_obj=2.325, cls=2.198
# Epoch [48/50], Iter [350/418], Loss: total=1.883, reg=10.880, containing_obj=7.182, no_obj=2.329, cls=2.210
# Epoch [48/50], Iter [400/418], Loss: total=1.880, reg=10.868, containing_obj=7.174, no_obj=2.324, cls=2.196
#
#
# Starting epoch 49 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [49/50], Iter [50/418], Loss: total=1.882, reg=10.717, containing_obj=7.040, no_obj=2.224, cls=2.605
# Epoch [49/50], Iter [100/418], Loss: total=1.861, reg=10.631, containing_obj=7.014, no_obj=2.307, cls=2.376
# Epoch [49/50], Iter [150/418], Loss: total=1.857, reg=10.591, containing_obj=7.078, no_obj=2.287, cls=2.327
# Epoch [49/50], Iter [200/418], Loss: total=1.895, reg=10.854, containing_obj=7.219, no_obj=2.259, cls=2.412
# Epoch [49/50], Iter [250/418], Loss: total=1.881, reg=10.784, containing_obj=7.172, no_obj=2.281, cls=2.330
# Epoch [49/50], Iter [300/418], Loss: total=1.867, reg=10.723, containing_obj=7.088, no_obj=2.286, cls=2.304
# Epoch [49/50], Iter [350/418], Loss: total=1.874, reg=10.768, containing_obj=7.137, no_obj=2.291, cls=2.292
# Epoch [49/50], Iter [400/418], Loss: total=1.869, reg=10.771, containing_obj=7.097, no_obj=2.288, cls=2.275
#
#
# Starting epoch 50 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [50/50], Iter [50/418], Loss: total=1.945, reg=11.507, containing_obj=7.197, no_obj=2.263, cls=2.368
# Epoch [50/50], Iter [100/418], Loss: total=1.914, reg=11.355, containing_obj=7.094, no_obj=2.282, cls=2.237
# Epoch [50/50], Iter [150/418], Loss: total=1.893, reg=11.178, containing_obj=7.193, no_obj=2.255, cls=2.095
# Epoch [50/50], Iter [200/418], Loss: total=1.883, reg=11.034, containing_obj=7.166, no_obj=2.250, cls=2.146
# Epoch [50/50], Iter [250/418], Loss: total=1.875, reg=10.957, containing_obj=7.143, no_obj=2.229, cls=2.166
# Epoch [50/50], Iter [300/418], Loss: total=1.861, reg=10.827, containing_obj=7.078, no_obj=2.256, cls=2.173
# Epoch [50/50], Iter [350/418], Loss: total=1.858, reg=10.844, containing_obj=7.041, no_obj=2.265, cls=2.151
# Epoch [50/50], Iter [400/418], Loss: total=1.867, reg=10.931, containing_obj=7.051, no_obj=2.254, cls=2.171
# ---Evaluate model on test samples---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [01:03<00:00, 78.14it/s]
# ---class aeroplane ap 0.48949686016397265---
# ---class bicycle ap 0.6651459822996479---
# ---class bird ap 0.5202000261658521---
# ---class boat ap 0.31524630130130443---
# ---class bottle ap 0.20253793362886185---
# ---class bus ap 0.6314166583372824---
# ---class car ap 0.6540527427067353---
# ---class cat ap 0.7401579464610579---
# ---class chair ap 0.3114961414618175---
# ---class cow ap 0.532215599739973---
# ---class diningtable ap 0.33695673176159274---
# ---class dog ap 0.6686899065925098---
# ---class horse ap 0.7012591816166902---
# ---class motorbike ap 0.6172773012595716---
# ---class person ap 0.5154162800210216---
# ---class pottedplant ap 0.2273744044909234---
# ---class sheep ap 0.4964776579839271---
# ---class sofa ap 0.4711032235616805---
# ---class train ap 0.6808916300043236---
# ---class tvmonitor ap 0.5318583236167992---
# ---map 0.5154635416587772---
# 49 [np.float64(0.48949686016397265), np.float64(0.6651459822996479), np.float64(0.5202000261658521), np.float64(0.31524630130130443), np.float64(0.20253793362886185), np.float64(0.6314166583372824), np.float64(0.6540527427067353), np.float64(0.7401579464610579), np.float64(0.3114961414618175), np.float64(0.532215599739973), np.float64(0.33695673176159274), np.float64(0.6686899065925098), np.float64(0.7012591816166902), np.float64(0.6172773012595716), np.float64(0.5154162800210216), np.float64(0.2273744044909234), np.float64(0.4964776579839271), np.float64(0.4711032235616805), np.float64(0.6808916300043236), np.float64(0.5318583236167992)]

# %% [markdown]
# # View example predictions

# %%
net.eval()

# select random image from test set
image_name = random.choice(test_dataset.fnames)
image = cv2.imread(os.path.join(file_root_test, image_name))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

print('predicting...')
result = predict_image(net, image_name, root_img_directory=file_root_test)
for left_up, right_bottom, class_name, _, prob in result:
    color = COLORS[VOC_CLASSES.index(class_name)]
    cv2.rectangle(image, left_up, right_bottom, color, 2)
    label = class_name + str(round(prob, 2))
    text_size, baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
    p1 = (left_up[0], left_up[1] - text_size[1])
    cv2.rectangle(image, (p1[0] - 2 // 2, p1[1] - 2 - baseline), (p1[0] + text_size[0], p1[1] + text_size[1]),
                  color, -1)
    cv2.putText(image, label, (p1[0], p1[1] + baseline), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255, 255, 255), 1, 8)

plt.figure(figsize = (15,15))
plt.imshow(image)
plt.savefig('yolo.png')
# Out:
# predicting...

# %%
# ================================================================
# VIDEO DETECTION – **ZERO** CHANGES TO YOUR EXISTING FUNCTIONS
# ================================================================
import cv2, torch, os, tempfile, uuid, shutil
from pathlib import Path

# 0)  -----  your stuff  ------------------------------------------
net = net            # ← you already loaded it in a previous cell
net.eval()
COLORS = COLORS
VOC_CLASSES = VOC_CLASSES
predict_image = predict_image   # ← the one you already wrote
# -----------------------------------------------------------------

# 1)  -----  video I/O  -------------------------------------------
src_video  = "cr7.mp4"      # 0 → webcam
out_video  = "siu.mp4"

cap = cv2.VideoCapture(src_video)
assert cap.isOpened(), f"Cannot open {src_video}"

fps  = cap.get(cv2.CAP_PROP_FPS) or 25
W, H = int(cap.get(3)), int(cap.get(4))
writer = cv2.VideoWriter(out_video,
                         cv2.VideoWriter_fourcc(*"mp4v"),
                         fps, (W, H))
print("Running… press q to stop.")

#   temp directory for frame snapshots
tmp_dir = tempfile.mkdtemp()

# 2)  -----  main loop  -------------------------------------------
while True:
    ok, frame_bgr = cap.read()
    if not ok: break

    # ---- save frame to a temp file (so predict_image can load it) ----
    tmp_name = f"{uuid.uuid4().hex}.jpg"
    tmp_path = os.path.join(tmp_dir, tmp_name)
    cv2.imwrite(tmp_path, frame_bgr)

    # run your *unchanged* predict_image()
    detections = predict_image(net, tmp_name, root_img_directory=tmp_dir)

    # delete the temp file right away
    os.remove(tmp_path)

    # ---- draw results (your old code) ---------------------------------
    for left_up, right_bottom, cls, _, prob in detections:
        color = COLORS[VOC_CLASSES.index(cls)]
        cv2.rectangle(frame_bgr, left_up, right_bottom, color, 2)
        label = f"{cls}{prob:.2f}"
        txt_sz, base = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, .4, 1)
        p1 = (left_up[0], left_up[1] - txt_sz[1])
        cv2.rectangle(frame_bgr,
                      (p1[0]-1, p1[1]-1-base),
                      (p1[0]+txt_sz[0]+1, p1[1]+txt_sz[1]+1),
                      color, -1)
        cv2.putText(frame_bgr, label, (p1[0], p1[1]+base),
                    cv2.FONT_HERSHEY_SIMPLEX, .4, (255,255,255), 1, 8)

    writer.write(frame_bgr)                 # save frame
    cv2.imshow("YOLO Video", frame_bgr)     # live preview
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# 3)  -----  clean‑up  --------------------------------------------
cap.release()
writer.release()
cv2.destroyAllWindows()
shutil.rmtree(tmp_dir)      # nuke the temp dir
print(f"Saved → {Path(out_video).resolve()}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 9
#       7 # 0)  -----  your stuff  ------------------------------------------
#       8 net = net            # ← you already loaded it in a previous cell
# ----> 9 net.eval()
#      10 COLORS = COLORS
#      11 VOC_CLASSES = VOC_CLASSES
#
# AttributeError: 'ellipsis' object has no attribute 'eval'

# %% [markdown]
# ## Evaluate on Test
#
# To evaluate detection results we use mAP (mean of average precision over each class)

# %%
test_aps = evaluate(net, test_dataset_file=annotation_file_test, img_root=file_root_test)
# Out:
# ---Evaluate model on test samples---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [00:55<00:00, 89.51it/s]
# ---class aeroplane ap 0.48949686016397265---
# ---class bicycle ap 0.6651459822996479---
# ---class bird ap 0.5202000261658521---
# ---class boat ap 0.31524630130130443---
# ---class bottle ap 0.20253793362886185---
# ---class bus ap 0.6314166583372824---
# ---class car ap 0.6540527427067353---
# ---class cat ap 0.7401579464610579---
# ---class chair ap 0.3114961414618175---
# ---class cow ap 0.532215599739973---
# ---class diningtable ap 0.33695673176159274---
# ---class dog ap 0.6686899065925098---
# ---class horse ap 0.7012591816166902---
# ---class motorbike ap 0.6172773012595716---
# ---class person ap 0.5154162800210216---
# ---class pottedplant ap 0.2273744044909234---
# ---class sheep ap 0.4964776579839271---
# ---class sofa ap 0.4711032235616805---
# ---class train ap 0.6808916300043236---
# ---class tvmonitor ap 0.5318583236167992---
# ---map 0.5154635416587772---

# %% [markdown]
# ### Cell added to get intermediate mAP values for students

# %%
network_paths = ['./checkpoints/detector_epoch_%d.pth' % epoch for epoch in [5, 10, 20, 30, 40]]+['./checkpoints/detector.pth']
for load_network_path in network_paths:
    print('Loading saved network from {}'.format(load_network_path))
    net_loaded =  resnet50().to(device)
    net_loaded.load_state_dict(torch.load(load_network_path))
    evaluate(net_loaded, test_dataset_file=annotation_file_test, img_root=file_root_test)
# Out:
# Loading saved network from ./checkpoints/detector_epoch_5.pth
# ---Evaluate model on test samples---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [00:54<00:00, 90.25it/s]
# ---class aeroplane ap 0.03343957115009747---
# ---class bicycle ap 0.13519782403495284---
# ---class bird ap 0.015212981744421908---
# ---class boat ap 0.0--- (no predictions for this class)
# ---class bottle ap 0.0--- (no predictions for this class)
# ---class bus ap 0.0--- (no predictions for this class)
# ---class car ap 0.3295691198839656---
# ---class cat ap 0.0--- (no predictions for this class)
# ---class chair ap 0.05435188822815862---
# ---class cow ap 0.0--- (no predictions for this class)
# ---class diningtable ap 0.0--- (no predictions for this class)
# ---class dog ap 0.09736027185157725---
# ---class horse ap 0.014511494252873564---
# ---class motorbike ap 0.0--- (no predictions for this class)
# ---class person ap 0.18906783544144307---
# ---class pottedplant ap 0.013139470151964594---
# ---class sheep ap 0.0--- (no predictions for this class)
# ---class sofa ap 0.0--- (no predictions for this class)
# ---class train ap 0.0--- (no predictions for this class)
# ---class tvmonitor ap 0.13473178709286654---
# ---map 0.05082911219161608---
# Loading saved network from ./checkpoints/detector_epoch_10.pth
# ---Evaluate model on test samples---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [01:00<00:00, 81.55it/s]
# ---class aeroplane ap 0.34989932288818687---
# ---class bicycle ap 0.347749872447871---
# ---class bird ap 0.26114045074733244---
# ---class boat ap 0.039101872783008675---
# ---class bottle ap 0.045094597350326435---
# ---class bus ap 0.28298013212583073---
# ---class car ap 0.562997963841209---
# ---class cat ap 0.5808022637047963---
# ---class chair ap 0.15085444631403966---
# ---class cow ap 0.15279777763804253---
# ---class diningtable ap 0.00022065313327449248---
# ---class dog ap 0.4941139987941897---
# ---class horse ap 0.4987407114910024---
# ---class motorbike ap 0.4859871679367955---
# ---class person ap 0.3374604076735571---
# ---class pottedplant ap 0.05606338423529933---
# ---class sheep ap 0.13503859403031945---
# ---class sofa ap 0.07154137878927797---
# ---class train ap 0.4825971397868719---
# ---class tvmonitor ap 0.3092732339215931---
# ---map 0.2822227684816413---
# Loading saved network from ./checkpoints/detector_epoch_20.pth
# ---Evaluate model on test samples---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [01:00<00:00, 81.77it/s]
# ---class aeroplane ap 0.44296481809908034---
# ---class bicycle ap 0.6230940740037425---
# ---class bird ap 0.45217916469617636---
# ---class boat ap 0.3006895600946399---
# ---class bottle ap 0.11523813531481153---
# ---class bus ap 0.5567940202462109---
# ---class car ap 0.6217628424729466---
# ---class cat ap 0.695847273961382---
# ---class chair ap 0.2627154048357202---
# ---class cow ap 0.38556272643041667---
# ---class diningtable ap 0.14563622209726773---
# ---class dog ap 0.5575604241897365---
# ---class horse ap 0.586404804855444---
# ---class motorbike ap 0.5363019002042206---
# ---class person ap 0.4456514710304127---
# ---class pottedplant ap 0.12951228186773017---
# ---class sheep ap 0.4183316742603158---
# ---class sofa ap 0.4524916392865595---
# ---class train ap 0.6296210822357743---
# ---class tvmonitor ap 0.43358836868059764---
# ---map 0.4395973944431593---
# Loading saved network from ./checkpoints/detector_epoch_30.pth
# ---Evaluate model on test samples---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [01:00<00:00, 81.48it/s]
# ---class aeroplane ap 0.49365909436860317---
# ---class bicycle ap 0.6173733117719948---
# ---class bird ap 0.47822380673038556---
# ---class boat ap 0.24777198705293527---
# ---class bottle ap 0.20670031068367786---
# ---class bus ap 0.6281217429323155---
# ---class car ap 0.5975602967959956---
# ---class cat ap 0.7375403652866828---
# ---class chair ap 0.28072183378769666---
# ---class cow ap 0.4518371189629482---
# ---class diningtable ap 0.28935111946845177---
# ---class dog ap 0.6421199345493434---
# ---class horse ap 0.6572141001607116---
# ---class motorbike ap 0.5713384414006486---
# ---class person ap 0.5074463424643786---
# ---class pottedplant ap 0.22345865635442957---
# ---class sheep ap 0.4761986751936339---
# ---class sofa ap 0.4040243445899557---
# ---class train ap 0.6411233717477263---
# ---class tvmonitor ap 0.5094504453118228---
# ---map 0.4830617649807169---
# Loading saved network from ./checkpoints/detector_epoch_40.pth
# ---Evaluate model on test samples---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [00:59<00:00, 82.77it/s]
# ---class aeroplane ap 0.5043034184702642---
# ---class bicycle ap 0.6731574703273904---
# ---class bird ap 0.4989357363109963---
# ---class boat ap 0.3151889286545504---
# ---class bottle ap 0.20254852425389352---
# ---class bus ap 0.6170274309879066---
# ---class car ap 0.6660200412955556---
# ---class cat ap 0.7168461337468057---
# ---class chair ap 0.30945530872993343---
# ---class cow ap 0.4992876671388011---
# ---class diningtable ap 0.33674424491949745---
# ---class dog ap 0.675496834693018---
# ---class horse ap 0.6865474576257347---
# ---class motorbike ap 0.6083418412554314---
# ---class person ap 0.5118856074194587---
# ---class pottedplant ap 0.2474946920371196---
# ---class sheep ap 0.5124764890474487---
# ---class sofa ap 0.4884130545659859---
# ---class train ap 0.6644140023752985---
# ---class tvmonitor ap 0.5165621655947288---
# ---map 0.512557352472491---
# Loading saved network from ./checkpoints/detector.pth
# ---Evaluate model on test samples---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4950/4950 [01:02<00:00, 79.58it/s]
# ---class aeroplane ap 0.48949686016397265---
# ---class bicycle ap 0.6651459822996479---
# ---class bird ap 0.5202000261658521---
# ---class boat ap 0.31524630130130443---
# ---class bottle ap 0.20253793362886185---
# ---class bus ap 0.6314166583372824---
# ---class car ap 0.6540527427067353---
# ---class cat ap 0.7401579464610579---
# ---class chair ap 0.3114961414618175---
# ---class cow ap 0.532215599739973---
# ---class diningtable ap 0.33695673176159274---
# ---class dog ap 0.6686899065925098---
# ---class horse ap 0.7012591816166902---
# ---class motorbike ap 0.6172773012595716---
# ---class person ap 0.5154162800210216---
# ---class pottedplant ap 0.2273744044909234---
# ---class sheep ap 0.4964776579839271---
# ---class sofa ap 0.4711032235616805---
# ---class train ap 0.6808916300043236---
# ---class tvmonitor ap 0.5318583236167992---
# ---map 0.5154635416587772---

# %%
output_submission_csv('my_solution.csv', test_aps)
